# %% [markdown]
# ## 🏴‍☠️ 🏴‍☠️ 🏴‍☠️ Introduktion til MicroPyton 🏴‍☠️ 🏴‍☠️ 🏴‍☠️
# *Hej alle sammen, i dag skal vi lære om nogle grundlæggende elementer i Python-programmering. Dette er vigtigt, fordi det giver os fundamentet til at forstå og skrive vores egne programmer. Vi vil kigge på variabler, datatyper, og nogle enkle matematiske operationer.*

# %% [markdown]
# #### **1. Variabler og Datatyper:**
#
# - **Variabler:**
#
# "Lad os starte med variabler. En variabel er som en kasse, hvor vi kan gemme information. Vi giver kassen et navn, så vi kan huske, hvad vi har gemt der. For eksempel:"
#
# ---
# ```Python
# navn = "Alice"
# alder = 10
# ```
# ---
# "Her har vi to variabler, 'navn' og 'alder'. 'Navn' gemmer en tekst, og 'alder' gemmer et tal."
#
# - **Datatyper:**
#
# "Der findes forskellige typer data, som vi kan gemme i variabler. De vigtigste er:
#
# Heltal (int), som er hele tal.
# Flydende tal (float), som er tal med decimaler.
# Strenge (str), som er tekst.
# Lister (list), som kan indeholde flere værdier."
#
#
# - **Kontrol af variabler:**
#
# "For at se, hvad der er gemt i variablerne, kan man få dem udskrevet ved at bruge kommandoen print. Det er her, kassens navn bliver anvendeligt."
#
# "Her er nogle eksempler:"
#
# ---
# ```Python
# heltal = 5
# print(heltal)
# flydende_tal = 3.14
# print(flydende_tal)
# tekst = "Hej Pirater - Her er en meget laaaaaaang tekst man ikke vil skrive flere gange, da man også risikere stave fejl. Derfor er variabler mega smarte"
# print(tekst)
# liste = [1, 2, 3, 4]
# print(liste)
# ```
# ---

# %% [markdown]
# #### **2. Basis matematiske operationer:**
#
# - Grundlæggende operationer:
# "Python kan også lave beregninger for os. Her er nogle grundlæggende matematiske operationer:
#
# Addition (+)
# Subtraktion (-)
# Multiplikation (*)
# Division (/)
# "Lad os se nogle eksempler:"
#
# ---
# ```Python
# a = 10
# b = 2
# sum = a + b        # Addition
# difference = a - b # Subtraktion
# produkt = a * b    # Multiplikation
# kvotient = a / b   # Division
# ```
# ---
#
# - **Brug af variabler i beregninger:**
#
# "Vi kan bruge variabler til at lave beregninger. For eksempel:"
#
# ---
# ```Python
# radius = 5
# omkreds = 2 * 3.14 * radius  # Beregning af en cirkels omkreds
# ```
# ---

# %% [markdown]
# #### **3. Tekst og basisoperationer:**
#
# - **Strengeoperationer:**
#
# "Strenge er tekst, og vi kan gøre mange ting med dem, ligesom at sammenkæde dem, gentage dem, og tage enkelte tegn ud. Her er nogle eksempler:"
#
# ---
# ```Python
# tekst1 = "Hej"
# tekst2 = " Verden"
# fuld_tekst = tekst1 + tekst2    # Sammenkædning
# gentaget_tekst = tekst1 * 3     # Gentagelse
# første_bogstav = tekst1[0]      # Indeksering
# ```
# ---
#
# "Vi kan bruge '+' til at sammenkæde to strenge, '*' til at gentage en streng flere gange, og '[]' til at få et bestemt tegn fra strengen."
#
# - **Lister og basisoperationer:**
#
# "Lister er som en samling af variabler, som vi kan gemme i én variabel. Vi kan tilføje, fjerne og få adgang til elementer i en liste. Her er nogle eksempler:"
#
# ---
# ```Python
# liste = [1, 2, 3, 4]
# liste.append(5)        # Tilføje element
# liste.remove(2)        # Fjerne element
# første_element = liste[0]  # Adgang til element
# ```
# ---
#
# "Med '.append()' kan vi tilføje et element til listen, med '.remove()' kan vi fjerne et element, og med '[]' kan vi få adgang til et bestemt element i listen."

# %% [markdown]
# #### **4. Funktioner:**
#
# "Nu skal vi tale om funktioner. En funktion er et stykke kode, som vi kan genbruge flere gange i vores program. Det hjælper os med at organisere vores kode og gøre den mere overskuelig. Vi definerer en funktion én gang og kan derefter kalde den, når vi har brug for den."
#
# - **Definition og Kald af Funktioner:**
# "Lad os starte med at se, hvordan vi definerer en funktion. Vi bruger nøgleordet 'def' efterfulgt af funktionens navn og parenteser. Inden i parenteserne kan vi skrive parametre, som er information, vi kan give til funktionen. Herefter kommer et kolon og indrykket kode, som er selve funktionens krop."
#
# ---
# ```Python
# def sig_hej():
#     print("Hej Verden!")
# ```
# ---
#
# "Her har vi defineret en simpel funktion, som hedder 'sig_hej'. Når vi kalder funktionen, udskriver den 'Hej Verden!'"
#
# - **Kalder Funktioner:**
#
# "Lad os nu se, hvordan vi kalder en funktion. Det er meget simpelt - vi skriver bare funktionens navn efterfulgt af parenteser."
#
# ---
# ```Python
# sig_hej()  # Dette kalder funktionen og udskriver "Hej Verden!"
# ```
# ---
#
# - **Funktioner med Parametre:**
#
# "Vi kan også lave funktioner, der tager imod parametre. Det betyder, at vi kan give funktionen forskellige værdier, som den kan arbejde med."
#
# ---
# ```Python
# def sig_hej_til(navn):
#     print(f"Hej {navn}!")
# ```
# ---
#
# "Her har vi defineret en funktion, der hedder 'sig_hej_til', som tager ét parameter, 'navn'. Når vi kalder funktionen, udskriver den 'Hej' efterfulgt af det navn, vi giver den."
#
# ---
# ```Python
# sig_hej_til("Alice")  # Udskriver "Hej Alice!"
# sig_hej_til("Bob")    # Udskriver "Hej Bob!"
# ```
# ---
#
# - **Returnere Værdier fra Funktioner:**
#
# "Funktioner kan også returnere værdier ved hjælp af nøgleordet 'return'. Det betyder, at funktionen kan give os et resultat, som vi kan bruge videre i vores program."
#
# ---
# ```Python
# def addere(a, b):
#     return a + b
#
# sum = addere(3, 5)
# print(sum)  # Udskriver 8
# ```
# ---

# %% [markdown]
# #### **5. Loops:**
#
# "Nu skal vi tale om loops. Et loop er et stykke kode, gentager sig selv flere gange i vores program. Loops kan hjælpe os til ikke at skulle skive den samme kode flere gange, hvis vi har en sekvens der skal gentages."
#
# - **For-Loop:**
#
# "Et for-loop kan feks. køre et fast antal gange, eller bruges til at gentages for hvert element der er i en liste:
#
# ```python
# # For-Loop der køre 6 gange
# for x in range(6):
#   print(x)
# ```
#
# ```python
# # For-Loop der køre en gang for hvert element i listen
# liste = [1, 2, 3, 4]
# for tal in liste:
#   print(tal)
# ```
#
# - **While-Loop**
#
# "Et While-Loop køre så længe et statement er sandt"
#
# ```python
# # While-Loop der køre 5 gange
# i = 1
# while i < 6: # Så længe `i` er mindre end 6
#   print(i)
#   i += 1
# ```
#
# ```python
# # Uendeligt Loop
# i = 1
# while True: # Så længe `True` er sandt, hmmm
#   print(i)
#   i += 1
# ```

# %% [markdown]
# ***Afslutning:***
#
# ***Dette var en introduktion til nogle grundlæggende elementer i Python. Husk, at variabler og datatyper er byggestenene i programmering, og matematiske operationer hjælper os med at lave beregninger. Med denne viden er I klar til at begynde at skrive jeres egne programmer og eksperimentere med kode. Lad os nu prøve nogle øvelser sammen!***
# <br>
# ***Til det vi bruge noget der hedder jupyter notebook, som er tilgængelig online: https://jupyter.org/try-jupyter/lab/***
#
# ![image.png](attachment:a279ec72-759b-481f-819d-cff5f65100a8.png)
