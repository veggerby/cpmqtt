# %% [markdown]
# # <img src="attachment:ffa3217f-dd07-47b4-be23-dc168e6ca695.png" alt="drawing" width="25"/> Micropython
#
# 1. Installerer Thonny
#
#     - ## thonny.org
#       ![image.png](attachment:3ad481bb-7b78-48a6-ba89-1802f45d2090.png)

# %% [markdown]
# ### Packages
#
# - umqtt.robust
